# %%
import numpy as np
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import os 
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# C:\Users\jhroe\AppData\Local\Temp\ipykernel_23660\2609811891.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data_path = f"{os.getcwd()}/Data/"

# %%
# Convert 1d vector of indices to 2d coordinates, by specifying the height of the image
def index_to_coord(vec, height):
    y = vec//height
    x = vec%height
    return x,y

# convert boolean mask of the cell to black and white image
def bound_to_2d(bound_vec, width, height):
    b = np.zeros(height*width, dtype=np.int8)
    b[bound_vec] = 1
    b = np.reshape(b,[width,height]).T
    return b

# return the pixel that is closest to the center of the cell
def avg_idx(xs, ys):
    return round(np.mean(xs)), round(np.mean(ys))

# convert empty celltype to unknown celltype and get rid of matlab formatting
def emp_to_nan(l):
    res = np.array([])
    for i in range(len(l)):
        try:
            res = np.append(res, l[i][0][0])
        except:
            res = np.append(res, 'Unknown')
    return res

# %%
# create a dictionary that contains all the information of all the patients
master_dict = {}
for i in range(1, 417):
    no = format(i, '03d')
    pat = 'LUAD_D' + no
    path_celltype = f'{data_path}/raw/LUAD_IMC_CellType/{pat}.mat'
    path_seg_nms = f'{data_path}/raw/LUAD_IMC_Segmentation/{pat}/nuclei_multiscale.mat'
    celltype = loadmat(path_celltype)  # load mat-file
    segm_nms = loadmat(path_seg_nms)  # load mat-file

    patientdict = {}
    height, width = segm_nms['nucleiImage'].shape
    celltype_list = emp_to_nan(celltype['cellTypes'])

    for cellno, cell in enumerate(segm_nms['Boundaries'][0]):
        xcell,ycell = index_to_coord(cell, height)
        x,y = avg_idx(xcell, ycell)
        c_type = celltype_list[cellno]
        patientdict[cellno] = np.array([x,y,c_type])
        
    master_dict[pat] = patientdict

master_dict['LUAD_D001']
# Out:
# {0: array(['93', '159', 'Cancer'], dtype='<U11'),
#  1: array(['74', '186', 'Tc'], dtype='<U11'),
#  2: array(['167', '131', 'Tc'], dtype='<U11'),
#  3: array(['134', '116', 'Cancer'], dtype='<U11'),
#  4: array(['142', '122', 'Endothelial cell'], dtype='<U16'),
#  5: array(['133', '152', 'Cl MAC'], dtype='<U11'),
#  6: array(['153', '101', 'B cell'], dtype='<U11'),
#  7: array(['91', '179', 'Th'], dtype='<U11'),
#  8: array(['141', '197', 'Cancer'], dtype='<U11'),
#  9: array(['144', '168', 'Unknown'], dtype='<U11'),
#  10: array(['120', '149', 'Th'], dtype='<U11'),
#  11: array(['170', '107', 'Alt MAC'], dtype='<U11'),
#  12: array(['197', '140', 'Cancer'], dtype='<U11'),
#  13: array(['198', '76', 'Cancer'], dtype='<U11'),
#  14: array(['130', '164', 'Cancer'], dtype='<U11'),
#  15: array(['114', '173', 'Cancer'], dtype='<U11'),
#  16: array(['178', '87', 'Cancer'], dtype='<U11'),
#  17: array(['115', '164', 'Cl MAC'], dtype='<U11'),
#  18: array(['196', '69', 'Cancer'], dtype='<U11'),
#  19: array(['181', '97', 'Treg'], dtype='<U11'),
#  20: array(['81', '186', 'Th'], dtype='<U11'),
#  21: array(['178', '142', 'Cancer'], dtype='<U11'),
#  22: array(['183', '269', 'Cl MAC'], dtype='<U11'),
#  23: array(['56', '316', 'Cancer'], dtype='<U11'),
#  24: array(['98', '343', 'Cancer'], dtype='<U11'),
#  25: array(['64', '243', 'Alt MAC'], dtype='<U11'),
#  26: array(['192', '302', 'Cancer'], dtype='<U11'),
#  27: array(['104', '278', 'T other'], dtype='<U11'),
#  28: array(['183', '305', 'Cancer'], dtype='<U11'),
#  29: array(['101', '380', 'Cancer'], dtype='<U11'),
#  30: array(['69', '286', 'Cancer'], dtype='<U11'),
#  31: array(['65', '299', 'Cancer'], dtype='<U11'),
#  32: array(['32', '225', 'Cl MAC'], dtype='<U11'),
#  33: array(['46', '238', 'Th'], dtype='<U11'),
#  34: array(['67', '251', 'Th'], dtype='<U11'),
#  35: array(['16', '361', 'Cancer'], dtype='<U11'),
#  36: array(['90', '244', 'Cl MAC'], dtype='<U11'),
#  37: array(['31', '328', 'Cancer'], dtype='<U11'),
#  38: array(['81', '277', 'Cancer'], dtype='<U11'),
#  39: array(['40', '303', 'Cancer'], dtype='<U11'),
#  40: array(['55', '231', 'Unknown'], dtype='<U11'),
#  41: array(['128', '311', 'Tc'], dtype='<U11'),
#  42: array(['119', '237', 'Th'], dtype='<U11'),
#  43: array(['9', '290', 'Cancer'], dtype='<U11'),
#  44: array(['54', '326', 'Cancer'], dtype='<U11'),
#  45: array(['97', '250', 'Cancer'], dtype='<U11'),
#  46: array(['63', '388', 'Cancer'], dtype='<U11'),
#  47: array(['62', '209', 'Unknown'], dtype='<U11'),
#  48: array(['38', '231', 'Neutrophils'], dtype='<U11'),
#  49: array(['156', '300', 'Cancer'], dtype='<U11'),
#  50: array(['134', '333', 'Cancer'], dtype='<U11'),
#  51: array(['24', '270', 'Cancer'], dtype='<U11'),
#  52: array(['100', '350', 'Cancer'], dtype='<U11'),
#  53: array(['134', '386', 'Endothelial cell'], dtype='<U16'),
#  54: array(['93', '267', 'Treg'], dtype='<U11'),
#  55: array(['2', '298', 'Cancer'], dtype='<U11'),
#  56: array(['190', '260', 'Cl MAC'], dtype='<U11'),
#  57: array(['77', '254', 'Cancer'], dtype='<U11'),
#  58: array(['46', '377', 'Cancer'], dtype='<U11'),
#  59: array(['149', '315', 'Cancer'], dtype='<U11'),
#  60: array(['59', '268', 'Treg'], dtype='<U11'),
#  61: array(['149', '337', 'Treg'], dtype='<U11'),
#  62: array(['30', '359', 'Cancer'], dtype='<U11'),
#  63: array(['133', '355', 'Th'], dtype='<U11'),
#  64: array(['53', '260', 'Endothelial cell'], dtype='<U16'),
#  65: array(['45', '279', 'Cancer'], dtype='<U11'),
#  66: array(['119', '258', 'Tc'], dtype='<U11'),
#  67: array(['68', '319', 'Cancer'], dtype='<U11'),
#  68: array(['68', '209', 'Unknown'], dtype='<U11'),
#  69: array(['123', '373', 'Th'], dtype='<U11'),
#  70: array(['78', '204', 'Unknown'], dtype='<U11'),
#  71: array(['34', '274', 'Tc'], dtype='<U11'),
#  72: array(['94', '310', 'Cancer'], dtype='<U11'),
#  73: array(['68', '231', 'Cancer'], dtype='<U11'),
#  74: array(['74', '272', 'Cancer'], dtype='<U11'),
#  75: array(['175', '295', 'Cancer'], dtype='<U11'),
#  76: array(['126', '346', 'Th'], dtype='<U11'),
#  77: array(['176', '398', 'Cancer'], dtype='<U11'),
#  78: array(['114', '227', 'Cancer'], dtype='<U11'),
#  79: array(['30', '339', 'Cancer'], dtype='<U11'),
#  80: array(['180', '342', 'Cancer'], dtype='<U11'),
#  81: array(['22', '346', 'Cancer'], dtype='<U11'),
#  82: array(['100', '329', 'Cancer'], dtype='<U11'),
#  83: array(['64', '274', 'Cancer'], dtype='<U11'),
#  84: array(['32', '268', 'Cancer'], dtype='<U11'),
#  85: array(['18', '307', 'Cancer'], dtype='<U11'),
#  86: array(['170', '367', 'Cancer'], dtype='<U11'),
#  87: array(['5', '366', 'Cancer'], dtype='<U11'),
#  88: array(['156', '318', 'Cancer'], dtype='<U11'),
#  89: array(['124', '256', 'Cancer'], dtype='<U11'),
#  90: array(['16', '290', 'Cancer'], dtype='<U11'),
#  91: array(['92', '396', 'Cancer'], dtype='<U11'),
#  92: array(['54', '385', 'Cancer'], dtype='<U11'),
#  93: array(['131', '302', 'Cl Mo'], dtype='<U11'),
#  94: array(['100', '290', 'Unknown'], dtype='<U11'),
#  95: array(['189', '388', 'Cancer'], dtype='<U11'),
#  96: array(['54', '587', 'Cancer'], dtype='<U11'),
#  97: array(['10', '416', 'Cancer'], dtype='<U11'),
#  98: array(['19', '429', 'Cl MAC'], dtype='<U11'),
#  99: array(['32', '576', 'Alt MAC'], dtype='<U11'),
#  100: array(['4', '407', 'Cancer'], dtype='<U11'),
#  101: array(['92', '432', 'Endothelial cell'], dtype='<U16'),
#  102: array(['122', '491', 'Cancer'], dtype='<U11'),
#  103: array(['23', '479', 'Mast cell'], dtype='<U11'),
#  104: array(['163', '460', 'Th'], dtype='<U11'),
#  105: array(['63', '564', 'Cancer'], dtype='<U11'),
#  106: array(['102', '577', 'Tc'], dtype='<U11'),
#  107: array(['32', '484', 'Mast cell'], dtype='<U11'),
#  108: array(['92', '521', 'Cancer'], dtype='<U11'),
#  109: array(['65', '527', 'Th'], dtype='<U11'),
#  110: array(['88', '509', 'Cancer'], dtype='<U11'),
#  111: array(['48', '469', 'Th'], dtype='<U11'),
#  112: array(['10', '434', 'Endothelial cell'], dtype='<U16'),
#  113: array(['47', '450', 'Cl MAC'], dtype='<U11'),
#  114: array(['4', '549', 'Cancer'], dtype='<U11'),
#  115: array(['59', '464', 'Cl Mo'], dtype='<U11'),
#  116: array(['71', '497', 'Cancer'], dtype='<U11'),
#  117: array(['101', '523', 'Cancer'], dtype='<U11'),
#  118: array(['195', '595', 'Endothelial cell'], dtype='<U16'),
#  119: array(['68', '460', 'Th'], dtype='<U11'),
#  120: array(['20', '499', 'Cancer'], dtype='<U11'),
#  121: array(['124', '415', 'Th'], dtype='<U11'),
#  122: array(['74', '551', 'B cell'], dtype='<U11'),
#  123: array(['68', '573', 'Cancer'], dtype='<U11'),
#  124: array(['8', '501', 'Endothelial cell'], dtype='<U16'),
#  125: array(['8', '449', 'Endothelial cell'], dtype='<U16'),
#  126: array(['140', '501', 'Cancer'], dtype='<U11'),
#  127: array(['137', '457', 'Cancer'], dtype='<U11'),
#  128: array(['38', '516', 'Th'], dtype='<U11'),
#  129: array(['147', '592', 'Endothelial cell'], dtype='<U16'),
#  130: array(['165', '425', 'Endothelial cell'], dtype='<U16'),
#  131: array(['44', '425', 'Cl MAC'], dtype='<U11'),
#  132: array(['79', '500', 'Cancer'], dtype='<U11'),
#  133: array(['129', '436', 'Cancer'], dtype='<U11'),
#  134: array(['57', '483', 'Th'], dtype='<U11'),
#  135: array(['30', '503', 'Cancer'], dtype='<U11'),
#  136: array(['185', '594', 'T other'], dtype='<U11'),
#  137: array(['48', '511', 'Unknown'], dtype='<U11'),
#  138: array(['30', '537', 'Cancer'], dtype='<U11'),
#  139: array(['60', '510', 'Th'], dtype='<U11'),
#  140: array(['148', '497', 'Cancer'], dtype='<U11'),
#  141: array(['135', '565', 'Cancer'], dtype='<U11'),
#  142: array(['51', '504', 'Tc'], dtype='<U11'),
#  143: array(['145', '566', 'Cancer'], dtype='<U11'),
#  144: array(['114', '429', 'Cancer'], dtype='<U11'),
#  145: array(['93', '533', 'Cancer'], dtype='<U11'),
#  146: array(['80', '493', 'Cancer'], dtype='<U11'),
#  147: array(['12', '540', 'Cancer'], dtype='<U11'),
#  148: array(['140', '592', 'Cancer'], dtype='<U11'),
#  149: array(['169', '482', 'Cancer'], dtype='<U11'),
#  150: array(['35', '533', 'Unknown'], dtype='<U11'),
#  151: array(['76', '480', 'Cancer'], dtype='<U11'),
#  152: array(['27', '420', 'Endothelial cell'], dtype='<U16'),
#  153: array(['20', '469', 'Endothelial cell'], dtype='<U16'),
#  154: array(['139', '446', 'Cancer'], dtype='<U11'),
#  155: array(['143', '481', 'Endothelial cell'], dtype='<U16'),
#  156: array(['44', '530', 'Unknown'], dtype='<U11'),
#  157: array(['17', '533', 'Cl Mo'], dtype='<U11'),
#  158: array(['31', '516', 'Th'], dtype='<U11'),
#  159: array(['98', '510', 'Cancer'], dtype='<U11'),
#  160: array(['112', '574', 'Cl MAC'], dtype='<U11'),
#  161: array(['38', '409', 'Cl MAC'], dtype='<U11'),
#  162: array(['75', '449', 'Endothelial cell'], dtype='<U16'),
#  163: array(['89', '486', 'Cancer'], dtype='<U11'),
#  164: array(['33', '551', 'Cancer'], dtype='<U11'),
#  165: array(['32', '459', 'Cancer'], dtype='<U11'),
#  166: array(['132', '503', 'Cancer'], dtype='<U11'),
#  167: array(['85', '442', 'Endothelial cell'], dtype='<U16'),
#  168: array(['72', '538', 'Endothelial cell'], dtype='<U16'),
#  169: array(['78', '513', 'Cancer'], dtype='<U11'),
#  170: array(['171', '504', 'Cancer'], dtype='<U11'),
#  171: array(['105', '407', 'Cl MAC'], dtype='<U11'),
#  172: array(['61', '498', 'Tc'], dtype='<U11'),
#  173: array(['96', '452', 'Tc'], dtype='<U11'),
#  174: array(['149', '449', 'Endothelial cell'], dtype='<U16'),
#  175: array(['27', '527', 'Cl Mo'], dtype='<U11'),
#  176: array(['150', '580', 'Non-Cl Mo'], dtype='<U11'),
#  177: array(['51', '491', 'Th'], dtype='<U11'),
#  178: array(['86', '455', 'Cancer'], dtype='<U11'),
#  179: array(['39', '478', 'Non-Cl Mo'], dtype='<U11'),
#  180: array(['87', '404', 'Cancer'], dtype='<U11'),
#  181: array(['102', '536', 'Cancer'], dtype='<U11'),
#  182: array(['45', '563', 'Cancer'], dtype='<U11'),
#  183: array(['20', '555', 'Cancer'], dtype='<U11'),
#  184: array(['4', '472', 'Cancer'], dtype='<U11'),
#  185: array(['71', '505', 'Int Mo'], dtype='<U11'),
#  186: array(['16', '518', 'Endothelial cell'], dtype='<U16'),
#  187: array(['75', '524', 'Th'], dtype='<U11'),
#  188: array(['7', '488', 'Cancer'], dtype='<U11'),
#  189: array(['63', '598', 'Unknown'], dtype='<U11'),
#  190: array(['179', '418', 'Cancer'], dtype='<U11'),
#  191: array(['29', '415', 'Endothelial cell'], dtype='<U16'),
#  192: array(['41', '417', 'Cancer'], dtype='<U11'),
#  193: array(['163', '448', 'Alt MAC'], dtype='<U11'),
#  194: array(['124', '568', 'Cancer'], dtype='<U11'),
#  195: array(['10', '701', 'Cancer'], dtype='<U11'),
#  196: array(['180', '658', 'Cancer'], dtype='<U11'),
#  197: array(['192', '670', 'Cancer'], dtype='<U11'),
#  198: array(['30', '686', 'Cancer'], dtype='<U11'),
#  199: array(['60', '725', 'Cancer'], dtype='<U11'),
#  200: array(['78', '609', 'Th'], dtype='<U11'),
#  201: array(['7', '732', 'Cancer'], dtype='<U11'),
#  202: array(['85', '767', 'Th'], dtype='<U11'),
#  203: array(['18', '693', 'Cancer'], dtype='<U11'),
#  204: array(['77', '761', 'Treg'], dtype='<U11'),
#  205: array(['46', '774', 'Unknown'], dtype='<U11'),
#  206: array(['88', '757', 'Cl MAC'], dtype='<U11'),
#  207: array(['26', '700', 'Cancer'], dtype='<U11'),
#  208: array(['68', '757', 'Treg'], dtype='<U11'),
#  209: array(['69', '647', 'Cancer'], dtype='<U11'),
#  210: array(['55', '659', 'Cancer'], dtype='<U11'),
#  211: array(['70', '620', 'Alt MAC'], dtype='<U11'),
#  212: array(['35', '707', 'Cancer'], dtype='<U11'),
#  213: array(['176', '682', 'B cell'], dtype='<U11'),
#  214: array(['68', '672', 'Cancer'], dtype='<U11'),
#  215: array(['86', '721', 'Cancer'], dtype='<U11'),
#  216: array(['10', '647', 'Endothelial cell'], dtype='<U16'),
#  217: array(['40', '635', 'Endothelial cell'], dtype='<U16'),
#  218: array(['132', '782', 'Unknown'], dtype='<U11'),
#  219: array(['154', '741', 'Cancer'], dtype='<U11'),
#  220: array(['99', '649', 'Endothelial cell'], dtype='<U16'),
#  221: array(['72', '726', 'Cancer'], dtype='<U11'),
#  222: array(['3', '724', 'Cancer'], dtype='<U11'),
#  223: array(['24', '738', 'Cl MAC'], dtype='<U11'),
#  224: array(['70', '782', 'Unknown'], dtype='<U11'),
#  225: array(['2', '615', 'Cancer'], dtype='<U11'),
#  226: array(['108', '736', 'Cancer'], dtype='<U11'),
#  227: array(['65', '690', 'Cancer'], dtype='<U11'),
#  228: array(['103', '765', 'Cl MAC'], dtype='<U11'),
#  229: array(['105', '622', 'Cl MAC'], dtype='<U11'),
#  230: array(['71', '745', 'Cancer'], dtype='<U11'),
#  231: array(['98', '669', 'Unknown'], dtype='<U11'),
#  232: array(['14', '625', 'Tc'], dtype='<U11'),
#  233: array(['136', '698', 'Cancer'], dtype='<U11'),
#  234: array(['98', '618', 'Th'], dtype='<U11'),
#  235: array(['93', '697', 'Cancer'], dtype='<U11'),
#  236: array(['33', '718', 'Cancer'], dtype='<U11'),
#  237: array(['27', '656', 'Unknown'], dtype='<U11'),
#  238: array(['2', '632', 'Unknown'], dtype='<U11'),
#  239: array(['22', '662', 'Endothelial cell'], dtype='<U16'),
#  240: array(['119', '773', 'Cl Mo'], dtype='<U11'),
#  241: array(['36', '727', 'Alt MAC'], dtype='<U11'),
#  242: array(['131', '664', 'Cl Mo'], dtype='<U11'),
#  243: array(['19', '635', 'Endothelial cell'], dtype='<U16'),
#  244: array(['37', '654', 'Unknown'], dtype='<U11'),
#  245: array(['96', '758', 'Cl MAC'], dtype='<U11'),
#  246: array(['18', '746', 'Unknown'], dtype='<U11'),
#  247: array(['89', '782', 'Unknown'], dtype='<U11'),
#  248: array(['94', '732', 'Cancer'], dtype='<U11'),
#  249: array(['36', '620', 'Endothelial cell'], dtype='<U16'),
#  250: array(['174', '688', 'B cell'], dtype='<U11'),
#  251: array(['174', '635', 'Non-Cl Mo'], dtype='<U11'),
#  252: array(['9', '631', 'Unknown'], dtype='<U11'),
#  253: array(['179', '690', 'Cl MAC'], dtype='<U11'),
#  254: array(['120', '616', 'Th'], dtype='<U11'),
#  255: array(['100', '722', 'Cancer'], dtype='<U11'),
#  256: array(['44', '652', 'Cancer'], dtype='<U11'),
#  257: array(['2', '654', 'Alt MAC'], dtype='<U11'),
#  258: array(['24', '669', 'Cl MAC'], dtype='<U11'),
#  259: array(['83', '739', 'Cancer'], dtype='<U11'),
#  260: array(['152', '690', 'B cell'], dtype='<U11'),
#  261: array(['84', '632', 'Unknown'], dtype='<U11'),
#  262: array(['34', '762', 'Treg'], dtype='<U11'),
#  263: array(['124', '705', 'Cancer'], dtype='<U11'),
#  264: array(['38', '769', 'Th'], dtype='<U11'),
#  265: array(['55', '617', 'Tc'], dtype='<U11'),
#  266: array(['4', '668', 'Cancer'], dtype='<U11'),
#  267: array(['50', '649', 'Endothelial cell'], dtype='<U16'),
#  268: array(['197', '625', 'Cancer'], dtype='<U11'),
#  269: array(['96', '659', 'Tc'], dtype='<U11'),
#  270: array(['23', '710', 'Cancer'], dtype='<U11'),
#  271: array(['166', '704', 'Cancer'], dtype='<U11'),
#  272: array(['103', '605', 'Cl MAC'], dtype='<U11'),
#  273: array(['87', '749', 'Cancer'], dtype='<U11'),
#  274: array(['151', '838', 'Cl Mo'], dtype='<U11'),
#  275: array(['72', '833', 'Unknown'], dtype='<U11'),
#  276: array(['145', '857', 'Cancer'], dtype='<U11'),
#  277: array(['195', '912', 'Cancer'], dtype='<U11'),
#  278: array(['101', '859', 'Cl MAC'], dtype='<U11'),
#  279: array(['157', '890', 'Cancer'], dtype='<U11'),
#  280: array(['99', '853', 'Cl MAC'], dtype='<U11'),
#  281: array(['149', '818', 'Unknown'], dtype='<U11'),
#  282: array(['163', '897', 'Tc'], dtype='<U11'),
#  283: array(['87', '850', 'Cl MAC'], dtype='<U11'),
#  284: array(['127', '827', 'Endothelial cell'], dtype='<U16'),
#  285: array(['162', '836', 'Tc'], dtype='<U11'),
#  286: array(['179', '893', 'Cancer'], dtype='<U11'),
#  287: array(['121', '866', 'Endothelial cell'], dtype='<U16'),
#  288: array(['184', '842', 'Cancer'], dtype='<U11'),
#  289: array(['140', '890', 'Th'], dtype='<U11'),
#  290: array(['70', '843', 'Treg'], dtype='<U11'),
#  291: array(['77', '844', 'T other'], dtype='<U11'),
#  292: array(['159', '879', 'Cancer'], dtype='<U11'),
#  293: array(['143', '882', 'Alt MAC'], dtype='<U11'),
#  294: array(['92', '863', 'B cell'], dtype='<U11'),
#  295: array(['167', '808', 'Unknown'], dtype='<U11'),
#  296: array(['170', '879', 'Cancer'], dtype='<U11'),
#  297: array(['133', '850', 'Cl Mo'], dtype='<U11'),
#  298: array(['190', '902', 'Cancer'], dtype='<U11'),
#  299: array(['91', '857', 'Cl MAC'], dtype='<U11'),
#  300: array(['88', '820', 'Endothelial cell'], dtype='<U16'),
#  301: array(['171', '869', 'Cancer'], dtype='<U11'),
#  302: array(['174', '858', 'Cancer'], dtype='<U11'),
#  303: array(['198', '813', 'Cancer'], dtype='<U11'),
#  304: array(['120', '852', 'Cl Mo'], dtype='<U11'),
#  305: array(['185', '807', 'Tc'], dtype='<U11'),
#  306: array(['258', '21', 'Cl MAC'], dtype='<U11'),
#  307: array(['382', '12', 'Unknown'], dtype='<U11'),
#  308: array(['321', '62', 'Tc'], dtype='<U11'),
#  309: array(['241', '38', 'Cancer'], dtype='<U11'),
#  310: array(['340', '93', 'Cancer'], dtype='<U11'),
#  311: array(['272', '56', 'Cancer'], dtype='<U11'),
#  312: array(['302', '17', 'Unknown'], dtype='<U11'),
#  313: array(['282', '61', 'Cancer'], dtype='<U11'),
#  314: array(['278', '46', 'Cancer'], dtype='<U11'),
#  315: array(['261', '63', 'Cancer'], dtype='<U11'),
#  316: array(['332', '5', 'Endothelial cell'], dtype='<U16'),
#  317: array(['344', '39', 'Th'], dtype='<U11'),
#  318: array(['329', '55', 'Cl MAC'], dtype='<U11'),
#  319: array(['332', '174', 'Treg'], dtype='<U11'),
#  320: array(['274', '29', 'Cancer'], dtype='<U11'),
#  321: array(['329', '68', 'Cancer'], dtype='<U11'),
#  322: array(['313', '39', 'Endothelial cell'], dtype='<U16'),
#  323: array(['286', '164', 'Endothelial cell'], dtype='<U16'),
#  324: array(['293', '9', 'Cancer'], dtype='<U11'),
#  325: array(['376', '5', 'Th'], dtype='<U11'),
#  326: array(['234', '196', 'Cancer'], dtype='<U11'),
#  327: array(['362', '102', 'Cancer'], dtype='<U11'),
#  328: array(['343', '15', 'Treg'], dtype='<U11'),
#  329: array(['268', '183', 'Cancer'], dtype='<U11'),
#  330: array(['344', '120', 'Cancer'], dtype='<U11'),
#  331: array(['345', '107', 'Cancer'], dtype='<U11'),
#  332: array(['313', '73', 'Cancer'], dtype='<U11'),
#  333: array(['352', '121', 'Cancer'], dtype='<U11'),
#  334: array(['316', '105', 'Cancer'], dtype='<U11'),
#  335: array(['228', '85', 'Cancer'], dtype='<U11'),
#  336: array(['357', '197', 'Th'], dtype='<U11'),
#  337: array(['325', '5', 'Tc'], dtype='<U11'),
#  338: array(['357', '61', 'Unknown'], dtype='<U11'),
#  339: array(['371', '49', 'Th'], dtype='<U11'),
#  340: array(['304', '102', 'Cancer'], dtype='<U11'),
#  341: array(['310', '2', 'Unknown'], dtype='<U11'),
#  342: array(['245', '157', 'Endothelial cell'], dtype='<U16'),
#  343: array(['371', '14', 'Th'], dtype='<U11'),
#  344: array(['377', '39', 'Th'], dtype='<U11'),
#  345: array(['337', '104', 'Cancer'], dtype='<U11'),
#  346: array(['324', '16', 'Th'], dtype='<U11'),
#  347: array(['272', '84', 'Cancer'], dtype='<U11'),
#  348: array(['306', '43', 'Treg'], dtype='<U11'),
#  349: array(['305', '54', 'Unknown'], dtype='<U11'),
#  350: array(['329', '162', 'Treg'], dtype='<U11'),
#  351: array(['357', '32', 'Th'], dtype='<U11'),
#  352: array(['365', '36', 'Treg'], dtype='<U11'),
#  353: array(['336', '41', 'Treg'], dtype='<U11'),
#  354: array(['264', '162', 'Th'], dtype='<U11'),
#  355: array(['348', '28', 'Cl MAC'], dtype='<U11'),
#  356: array(['277', '193', 'Cancer'], dtype='<U11'),
#  357: array(['351', '11', 'Th'], dtype='<U11'),
#  358: array(['247', '188', 'Cancer'], dtype='<U11'),
#  359: array(['398', '50', 'Cancer'], dtype='<U11'),
#  360: array(['357', '164', 'Th'], dtype='<U11'),
#  361: array(['247', '142', 'Tc'], dtype='<U11'),
#  362: array(['269', '168', 'Endothelial cell'], dtype='<U16'),
#  363: array(['277', '140', 'Unknown'], dtype='<U11'),
#  364: array(['328', '102', 'Cancer'], dtype='<U11'),
#  365: array(['252', '110', 'Cancer'], dtype='<U11'),
#  366: array(['322', '40', 'Th'], dtype='<U11'),
#  367: array(['314', '98', 'Cancer'], dtype='<U11'),
#  368: array(['365', '46', 'Cl Mo'], dtype='<U11'),
#  369: array(['327', '33', 'Th'], dtype='<U11'),
#  370: array(['269', '150', 'Th'], dtype='<U11'),
#  371: array(['291', '54', 'Cancer'], dtype='<U11'),
#  372: array(['285', '138', 'Unknown'], dtype='<U11'),
#  373: array(['301', '72', 'Cancer'], dtype='<U11'),
#  374: array(['303', '34', 'Endothelial cell'], dtype='<U16'),
#  375: array(['257', '191', 'Cancer'], dtype='<U11'),
#  376: array(['278', '149', 'Endothelial cell'], dtype='<U16'),
#  377: array(['388', '104', 'Cl Mo'], dtype='<U11'),
#  378: array(['313', '148', 'Unknown'], dtype='<U11'),
#  379: array(['331', '94', 'Cancer'], dtype='<U11'),
#  380: array(['384', '63', 'Tc'], dtype='<U11'),
#  381: array(['352', '21', 'Th'], dtype='<U11'),
#  382: array(['391', '182', 'Th'], dtype='<U11'),
#  383: array(['289', '178', 'Cancer'], dtype='<U11'),
#  384: array(['333', '49', 'Th'], dtype='<U11'),
#  385: array(['381', '115', 'Th'], dtype='<U11'),
#  386: array(['391', '47', 'Cancer'], dtype='<U11'),
#  387: array(['307', '130', 'Cancer'], dtype='<U11'),
#  388: array(['251', '52', 'Cancer'], dtype='<U11'),
#  389: array(['330', '84', 'Cancer'], dtype='<U11'),
#  390: array(['312', '24', 'Endothelial cell'], dtype='<U16'),
#  391: array(['388', '131', 'Th'], dtype='<U11'),
#  392: array(['322', '77', 'Cancer'], dtype='<U11'),
#  393: array(['227', '108', 'Cancer'], dtype='<U11'),
#  394: array(['208', '151', 'Cancer'], dtype='<U11'),
#  395: array(['255', '15', 'Cancer'], dtype='<U11'),
#  396: array(['368', '161', 'Alt MAC'], dtype='<U11'),
#  397: array(['363', '18', 'Tc'], dtype='<U11'),
#  398: array(['342', '224', 'Cancer'], dtype='<U11'),
#  399: array(['263', '362', 'Cancer'], dtype='<U11'),
#  400: array(['293', '279', 'Cancer'], dtype='<U11'),
#  401: array(['249', '315', 'Cl MAC'], dtype='<U11'),
#  402: array(['339', '233', 'Cancer'], dtype='<U11'),
#  403: array(['208', '323', 'Cancer'], dtype='<U11'),
#  404: array(['340', '366', 'Cancer'], dtype='<U11'),
#  405: array(['313', '312', 'Cancer'], dtype='<U11'),
#  406: array(['210', '346', 'Cancer'], dtype='<U11'),
#  407: array(['385', '377', 'Tc'], dtype='<U11'),
#  408: array(['280', '288', 'Cancer'], dtype='<U11'),
#  409: array(['356', '395', 'T other'], dtype='<U11'),
#  410: array(['255', '307', 'Cancer'], dtype='<U11'),
#  411: array(['336', '358', 'Cancer'], dtype='<U11'),
#  412: array(['284', '297', 'Tc'], dtype='<U11'),
#  413: array(['212', '256', 'Alt MAC'], dtype='<U11'),
#  414: array(['367', '294', 'Cancer'], dtype='<U11'),
#  415: array(['342', '257', 'Cancer'], dtype='<U11'),
#  416: array(['387', '246', 'Unknown'], dtype='<U11'),
#  417: array(['217', '364', 'Cancer'], dtype='<U11'),
#  418: array(['361', '205', 'Unknown'], dtype='<U11'),
#  419: array(['341', '327', 'Cancer'], dtype='<U11'),
#  420: array(['343', '241', 'Cancer'], dtype='<U11'),
#  421: array(['275', '315', 'Cancer'], dtype='<U11'),
#  422: array(['263', '303', 'Cancer'], dtype='<U11'),
#  423: array(['397', '321', 'T other'], dtype='<U11'),
#  424: array(['397', '279', 'Endothelial cell'], dtype='<U16'),
#  425: array(['359', '245', 'Unknown'], dtype='<U11'),
#  426: array(['377', '364', 'Unknown'], dtype='<U11'),
#  427: array(['355', '317', 'Endothelial cell'], dtype='<U16'),
#  428: array(['292', '307', 'Cancer'], dtype='<U11'),
#  429: array(['262', '345', 'Cancer'], dtype='<U11'),
#  430: array(['372', '306', 'Th'], dtype='<U11'),
#  431: array(['330', '272', 'Endothelial cell'], dtype='<U16'),
#  432: array(['314', '278', 'Th'], dtype='<U11'),
#  433: array(['374', '371', 'Endothelial cell'], dtype='<U16'),
#  434: array(['288', '286', 'Cancer'], dtype='<U11'),
#  435: array(['299', '300', 'Endothelial cell'], dtype='<U16'),
#  436: array(['330', '286', 'Tc'], dtype='<U11'),
#  437: array(['302', '310', 'Cancer'], dtype='<U11'),
#  438: array(['379', '210', 'Alt MAC'], dtype='<U11'),
#  439: array(['340', '379', 'Cancer'], dtype='<U11'),
#  440: array(['383', '326', 'Unknown'], dtype='<U11'),
#  441: array(['397', '291', 'Unknown'], dtype='<U11'),
#  442: array(['282', '332', 'Cancer'], dtype='<U11'),
#  443: array(['278', '322', 'Cancer'], dtype='<U11'),
#  444: array(['209', '384', 'Cancer'], dtype='<U11'),
#  445: array(['392', '308', 'Non-Cl Mo'], dtype='<U11'),
#  446: array(['388', '313', 'Non-Cl Mo'], dtype='<U11'),
#  447: array(['253', '397', 'Cl MAC'], dtype='<U11'),
#  448: array(['392', '283', 'Cl Mo'], dtype='<U11'),
#  449: array(['357', '266', 'Cancer'], dtype='<U11'),
#  450: array(['361', '337', 'Th'], dtype='<U11'),
#  451: array(['247', '383', 'Cl Mo'], dtype='<U11'),
#  452: array(['372', '231', 'Unknown'], dtype='<U11'),
#  453: array(['331', '255', 'Cancer'], dtype='<U11'),
#  454: array(['239', '353', 'Cl MAC'], dtype='<U11'),
#  455: array(['356', '276', 'Cancer'], dtype='<U11'),
#  456: array(['244', '568', 'Cancer'], dtype='<U11'),
#  457: array(['356', '426', 'Cancer'], dtype='<U11'),
#  458: array(['296', '473', 'Cancer'], dtype='<U11'),
#  459: array(['262', '581', 'Cancer'], dtype='<U11'),
#  460: array(['300', '417', 'Cancer'], dtype='<U11'),
#  461: array(['275', '457', 'Cancer'], dtype='<U11'),
#  462: array(['300', '584', 'Endothelial cell'], dtype='<U16'),
#  463: array(['324', '494', 'Cancer'], dtype='<U11'),
#  464: array(['233', '473', 'Endothelial cell'], dtype='<U16'),
#  465: array(['275', '573', 'Endothelial cell'], dtype='<U16'),
#  466: array(['264', '405', 'Endothelial cell'], dtype='<U16'),
#  467: array(['246', '420', 'Unknown'], dtype='<U11'),
#  468: array(['221', '563', 'Cl MAC'], dtype='<U11'),
#  469: array(['317', '448', 'Non-Cl Mo'], dtype='<U11'),
#  470: array(['299', '504', 'Cancer'], dtype='<U11'),
#  471: array(['302', '576', 'Endothelial cell'], dtype='<U16'),
#  472: array(['299', '491', 'Cancer'], dtype='<U11'),
#  473: array(['272', '419', 'Unknown'], dtype='<U11'),
#  474: array(['228', '501', 'Tc'], dtype='<U11'),
#  475: array(['325', '597', 'Cancer'], dtype='<U11'),
#  476: array(['344', '545', 'Cl Mo'], dtype='<U11'),
#  477: array(['300', '456', 'Cancer'], dtype='<U11'),
#  478: array(['331', '510', 'Endothelial cell'], dtype='<U16'),
#  479: array(['260', '570', 'Cancer'], dtype='<U11'),
#  480: array(['211', '572', 'Tc'], dtype='<U11'),
#  481: array(['382', '489', 'Cancer'], dtype='<U11'),
#  482: array(['222', '519', 'Tc'], dtype='<U11'),
#  483: array(['390', '416', 'B cell'], dtype='<U11'),
#  484: array(['386', '405', 'Tc'], dtype='<U11'),
#  485: array(['344', '537', 'Endothelial cell'], dtype='<U16'),
#  486: array(['315', '429', 'Th'], dtype='<U11'),
#  487: array(['307', '487', 'Cancer'], dtype='<U11'),
#  488: array(['226', '485', 'Cancer'], dtype='<U11'),
#  489: array(['337', '459', 'Unknown'], dtype='<U11'),
#  490: array(['344', '516', 'Treg'], dtype='<U11'),
#  491: array(['219', '408', 'Unknown'], dtype='<U11'),
#  492: array(['239', '466', 'Endothelial cell'], dtype='<U16'),
#  493: array(['312', '501', 'Cancer'], dtype='<U11'),
#  494: array(['290', '426', 'Endothelial cell'], dtype='<U16'),
#  495: array(['242', '451', 'Cancer'], dtype='<U11'),
#  496: array(['257', '493', 'Cancer'], dtype='<U11'),
#  497: array(['346', '556', 'Non-Cl Mo'], dtype='<U11'),
#  498: array(['394', '621', 'Cancer'], dtype='<U11'),
#  499: array(['259', '634', 'Cancer'], dtype='<U11'),
#  500: array(['244', '662', 'Cancer'], dtype='<U11'),
#  501: array(['303', '765', 'Th'], dtype='<U11'),
#  502: array(['308', '779', 'Unknown'], dtype='<U11'),
#  503: array(['226', '758', 'Treg'], dtype='<U11'),
#  504: array(['293', '708', 'Th'], dtype='<U11'),
#  505: array(['344', '675', 'Cancer'], dtype='<U11'),
#  506: array(['281', '768', 'Endothelial cell'], dtype='<U16'),
#  507: array(['234', '652', 'Cancer'], dtype='<U11'),
#  508: array(['354', '764', 'Unknown'], dtype='<U11'),
#  509: array(['292', '749', 'Endothelial cell'], dtype='<U16'),
#  510: array(['227', '645', 'Cancer'], dtype='<U11'),
#  511: array(['290', '771', 'Neutrophils'], dtype='<U11'),
#  512: array(['258', '684', 'Unknown'], dtype='<U11'),
#  513: array(['238', '675', 'Unknown'], dtype='<U11'),
#  514: array(['236', '736', 'Th'], dtype='<U11'),
#  515: array(['270', '766', 'Cl MAC'], dtype='<U11'),
#  516: array(['348', '781', 'Neutrophils'], dtype='<U11'),
#  517: array(['235', '704', 'Tc'], dtype='<U11'),
#  518: array(['329', '678', 'Unknown'], dtype='<U11'),
#  519: array(['285', '755', 'Alt MAC'], dtype='<U11'),
#  520: array(['321', '694', 'Endothelial cell'], dtype='<U16'),
#  521: array(['291', '621', 'Cancer'], dtype='<U11'),
#  522: array(['337', '667', 'Cancer'], dtype='<U11'),
#  523: array(['308', '624', 'Endothelial cell'], dtype='<U16'),
#  524: array(['332', '692', 'Tc'], dtype='<U11'),
#  525: array(['306', '641', 'Unknown'], dtype='<U11'),
#  526: array(['206', '649', 'Unknown'], dtype='<U11'),
#  527: array(['376', '769', 'Unknown'], dtype='<U11'),
#  528: array(['355', '719', 'Endothelial cell'], dtype='<U16'),
#  529: array(['300', '606', 'Endothelial cell'], dtype='<U16'),
#  530: array(['380', '752', 'Endothelial cell'], dtype='<U16'),
#  531: array(['265', '738', 'Cl MAC'], dtype='<U11'),
#  532: array(['381', '739', 'Endothelial cell'], dtype='<U16'),
#  533: array(['255', '666', 'Cancer'], dtype='<U11'),
#  534: array(['388', '748', 'Endothelial cell'], dtype='<U16'),
#  535: array(['366', '619', 'Cancer'], dtype='<U11'),
#  536: array(['395', '746', 'Cl Mo'], dtype='<U11'),
#  537: array(['270', '677', 'Cl MAC'], dtype='<U11'),
#  538: array(['254', '775', 'Cancer'], dtype='<U11'),
#  539: array(['398', '695', 'Endothelial cell'], dtype='<U16'),
#  540: array(['286', '682', 'Th'], dtype='<U11'),
#  541: array(['216', '609', 'Cancer'], dtype='<U11'),
#  542: array(['316', '675', 'Endothelial cell'], dtype='<U16'),
#  543: array(['286', '650', 'Cancer'], dtype='<U11'),
#  544: array(['316', '687', 'Non-Cl Mo'], dtype='<U11'),
#  545: array(['321', '619', 'Cancer'], dtype='<U11'),
#  546: array(['327', '665', 'Cancer'], dtype='<U11'),
#  547: array(['232', '696', 'Cancer'], dtype='<U11'),
#  548: array(['238', '767', 'Tc'], dtype='<U11'),
#  549: array(['350', '695', 'Tc'], dtype='<U11'),
#  550: array(['352', '636', 'Cancer'], dtype='<U11'),
#  551: array(['285', '737', 'Endothelial cell'], dtype='<U16'),
#  552: array(['340', '755', 'Cl Mo'], dtype='<U11'),
#  553: array(['265', '773', 'Cancer'], dtype='<U11'),
#  554: array(['301', '672', 'Endothelial cell'], dtype='<U16'),
#  555: array(['244', '786', 'Cancer'], dtype='<U11'),
#  556: array(['276', '612', 'Cancer'], dtype='<U11'),
#  557: array(['299', '822', 'Cancer'], dtype='<U11'),
#  558: array(['350', '879', 'Cancer'], dtype='<U11'),
#  559: array(['228', '888', 'Cancer'], dtype='<U11'),
#  560: array(['330', '959', 'Th'], dtype='<U11'),
#  561: array(['284', '951', 'Endothelial cell'], dtype='<U16'),
#  562: array(['378', '898', 'Cl Mo'], dtype='<U11'),
#  563: array(['379', '838', 'Cancer'], dtype='<U11'),
#  564: array(['304', '992', 'Endothelial cell'], dtype='<U16'),
#  565: array(['253', '890', 'Cancer'], dtype='<U11'),
#  566: array(['363', '909', 'Cancer'], dtype='<U11'),
#  567: array(['321', '846', 'Cancer'], dtype='<U11'),
#  568: array(['291', '991', 'Endothelial cell'], dtype='<U16'),
#  569: array(['235', '975', 'Endothelial cell'], dtype='<U16'),
#  570: array(['245', '997', 'Unknown'], dtype='<U11'),
#  571: array(['261', '874', 'Non-Cl Mo'], dtype='<U11'),
#  572: array(['249', '840', 'Cancer'], dtype='<U11'),
#  573: array(['290', '923', 'Cancer'], dtype='<U11'),
#  574: array(['282', '841', 'Cancer'], dtype='<U11'),
#  575: array(['303', '950', 'Endothelial cell'], dtype='<U16'),
#  576: array(['332', '945', 'Cancer'], dtype='<U11'),
#  577: array(['300', '974', 'Unknown'], dtype='<U11'),
#  578: array(['386', '962', 'Cancer'], dtype='<U11'),
#  579: array(['361', '819', 'Cancer'], dtype='<U11'),
#  580: array(['313', '963', 'Th'], dtype='<U11'),
#  581: array(['329', '837', 'Cancer'], dtype='<U11'),
#  582: array(['248', '879', 'Cancer'], dtype='<U11'),
#  583: array(['252', '849', 'Cancer'], dtype='<U11'),
#  584: array(['300', '943', 'Cancer'], dtype='<U11'),
#  585: array(['355', '890', 'Cancer'], dtype='<U11'),
#  586: array(['298', '860', 'Tc'], dtype='<U11'),
#  587: array(['384', '972', 'Cancer'], dtype='<U11'),
#  588: array(['264', '905', 'Endothelial cell'], dtype='<U16'),
#  589: array(['302', '890', 'Cancer'], dtype='<U11'),
#  590: array(['358', '918', 'Cl Mo'], dtype='<U11'),
#  591: array(['347', '988', 'Th'], dtype='<U11'),
#  592: array(['328', '858', 'Tc'], dtype='<U11'),
#  593: array(['316', '997', 'Th'], dtype='<U11'),
#  594: array(['238', '841', 'Cancer'], dtype='<U11'),
#  595: array(['343', '994', 'Th'], dtype='<U11'),
#  596: array(['271', '907', 'Endothelial cell'], dtype='<U16'),
#  597: array(['301', '912', 'Cancer'], dtype='<U11'),
#  598: array(['244', '926', 'Neutrophils'], dtype='<U11'),
#  599: array(['212', '826', 'Cancer'], dtype='<U11'),
#  600: array(['340', '813', 'Cancer'], dtype='<U11'),
#  601: array(['317', '870', 'Int Mo'], dtype='<U11'),
#  602: array(['325', '822', 'Cancer'], dtype='<U11'),
#  603: array(['302', '882', 'Unknown'], dtype='<U11'),
#  604: array(['368', '955', 'Cl Mo'], dtype='<U11'),
#  605: array(['315', '955', 'Th'], dtype='<U11'),
#  606: array(['371', '850', 'Cancer'], dtype='<U11'),
#  607: array(['350', '858', 'Cancer'], dtype='<U11'),
#  608: array(['236', '909', 'Alt MAC'], dtype='<U11'),
#  609: array(['303', '962', 'Unknown'], dtype='<U11'),
#  610: array(['570', '19', 'Cancer'], dtype='<U11'),
#  611: array(['542', '124', 'Cancer'], dtype='<U11'),
#  612: array(['515', '3', 'Cl MAC'], dtype='<U11'),
#  613: array(['597', '17', 'Cancer'], dtype='<U11'),
#  614: array(['506', '53', 'Cancer'], dtype='<U11'),
#  615: array(['564', '67', 'Cancer'], dtype='<U11'),
#  616: array(['570', '184', 'Cancer'], dtype='<U11'),
#  617: array(['596', '91', 'Endothelial cell'], dtype='<U16'),
#  618: array(['417', '16', 'Th'], dtype='<U11'),
#  619: array(['469', '73', 'Unknown'], dtype='<U11'),
#  620: array(['473', '60', 'Unknown'], dtype='<U11'),
#  621: array(['434', '90', 'Unknown'], dtype='<U11'),
#  622: array(['515', '50', 'Cancer'], dtype='<U11'),
#  623: array(['438', '55', 'Cl MAC'], dtype='<U11'),
#  624: array(['418', '88', 'Tc'], dtype='<U11'),
#  625: array(['501', '154', 'Endothelial cell'], dtype='<U16'),
#  626: array(['475', '104', 'Cancer'], dtype='<U11'),
#  627: array(['440', '46', 'Unknown'], dtype='<U11'),
#  628: array(['411', '73', 'Cl MAC'], dtype='<U11'),
#  629: array(['440', '26', 'Endothelial cell'], dtype='<U16'),
#  630: array(['476', '29', 'Alt MAC'], dtype='<U11'),
#  631: array(['498', '20', 'Endothelial cell'], dtype='<U16'),
#  632: array(['574', '63', 'Cancer'], dtype='<U11'),
#  633: array(['576', '70', 'Cancer'], dtype='<U11'),
#  634: array(['425', '62', 'Cl MAC'], dtype='<U11'),
#  635: array(['504', '3', 'Alt MAC'], dtype='<U11'),
#  636: array(['470', '46', 'Unknown'], dtype='<U11'),
#  637: array(['409', '61', 'Cl Mo'], dtype='<U11'),
#  638: array(['547', '56', 'Cancer'], dtype='<U11'),
#  639: array(['492', '179', 'T other'], dtype='<U11'),
#  640: array(['422', '40', 'Th'], dtype='<U11'),
#  641: array(['468', '26', 'Th'], dtype='<U11'),
#  642: array(['558', '9', 'Cancer'], dtype='<U11'),
#  643: array(['547', '4', 'Unknown'], dtype='<U11'),
#  644: array(['559', '85', 'Endothelial cell'], dtype='<U16'),
#  645: array(['564', '79', 'Endothelial cell'], dtype='<U16'),
#  646: array(['538', '50', 'Unknown'], dtype='<U11'),
#  647: array(['537', '158', 'Tc'], dtype='<U11'),
#  648: array(['466', '35', 'Th'], dtype='<U11'),
#  649: array(['462', '84', 'Cl MAC'], dtype='<U11'),
#  650: array(['465', '89', 'Cl MAC'], dtype='<U11'),
#  651: array(['487', '34', 'Neutrophils'], dtype='<U11'),
#  652: array(['496', '10', 'Int Mo'], dtype='<U11'),
#  653: array(['598', '153', 'Tc'], dtype='<U11'),
#  654: array(['591', '78', 'Neutrophils'], dtype='<U11'),
#  655: array(['452', '18', 'Endothelial cell'], dtype='<U16'),
#  656: array(['459', '62', 'Endothelial cell'], dtype='<U16'),
#  657: array(['503', '173', 'Endothelial cell'], dtype='<U16'),
#  658: array(['535', '37', 'Cancer'], dtype='<U11'),
#  659: array(['460', '23', 'Endothelial cell'], dtype='<U16'),
#  660: array(['465', '4', 'Endothelial cell'], dtype='<U16'),
#  661: array(['539', '92', 'Cancer'], dtype='<U11'),
#  662: array(['495', '99', 'Cancer'], dtype='<U11'),
#  663: array(['492', '16', 'Endothelial cell'], dtype='<U16'),
#  664: array(['457', '115', 'Unknown'], dtype='<U11'),
#  665: array(['511', '150', 'Endothelial cell'], dtype='<U16'),
#  666: array(['533', '29', 'Cancer'], dtype='<U11'),
#  667: array(['552', '62', 'Cancer'], dtype='<U11'),
#  668: array(['581', '99', 'Unknown'], dtype='<U11'),
#  669: array(['431', '3', 'Unknown'], dtype='<U11'),
#  670: array(['491', '143', 'Cancer'], dtype='<U11'),
#  671: array(['570', '88', 'Endothelial cell'], dtype='<U16'),
#  672: array(['418', '57', 'Unknown'], dtype='<U11'),
#  673: array(['417', '4', 'Unknown'], dtype='<U11'),
#  674: array(['574', '10', 'Unknown'], dtype='<U11'),
#  675: array(['452', '66', 'Endothelial cell'], dtype='<U16'),
#  676: array(['517', '58', 'Cancer'], dtype='<U11'),
#  677: array(['542', '85', 'Cancer'], dtype='<U11'),
#  678: array(['438', '171', 'Endothelial cell'], dtype='<U16'),
#  679: array(['422', '10', 'Unknown'], dtype='<U11'),
#  680: array(['531', '66', 'Unknown'], dtype='<U11'),
#  681: array(['486', '21', 'Endothelial cell'], dtype='<U16'),
#  682: array(['597', '133', 'Unknown'], dtype='<U11'),
#  683: array(['414', '45', 'Cancer'], dtype='<U11'),
#  684: array(['517', '21', 'Unknown'], dtype='<U11'),
#  685: array(['524', '53', 'Unknown'], dtype='<U11'),
#  686: array(['563', '99', 'Cancer'], dtype='<U11'),
#  687: array(['458', '44', 'T other'], dtype='<U11'),
#  688: array(['588', '157', 'Cl Mo'], dtype='<U11'),
#  689: array(['590', '2', 'Unknown'], dtype='<U11'),
#  690: array(['448', '81', 'Cl Mo'], dtype='<U11'),
#  691: array(['431', '37', 'Th'], dtype='<U11'),
#  692: array(['505', '33', 'Unknown'], dtype='<U11'),
#  693: array(['503', '191', 'Th'], dtype='<U11'),
#  694: array(['499', '196', 'Unknown'], dtype='<U11'),
#  695: array(['522', '21', 'Cancer'], dtype='<U11'),
#  696: array(['555', '94', 'Cancer'], dtype='<U11'),
#  697: array(['594', '115', 'Cl Mo'], dtype='<U11'),
#  698: array(['480', '16', 'Treg'], dtype='<U11'),
#  699: array(['483', '60', 'Unknown'], dtype='<U11'),
#  700: array(['535', '82', 'Endothelial cell'], dtype='<U16'),
#  701: array(['529', '11', 'Cancer'], dtype='<U11'),
#  702: array(['418', '188', 'Unknown'], dtype='<U11'),
#  703: array(['521', '97', 'Cancer'], dtype='<U11'),
#  704: array(['469', '17', 'Cl Mo'], dtype='<U11'),
#  705: array(['428', '20', 'Th'], dtype='<U11'),
#  706: array(['567', '252', 'Cancer'], dtype='<U11'),
#  707: array(['553', '335', 'Cancer'], dtype='<U11'),
#  708: array(['416', '355', 'Mast cell'], dtype='<U11'),
#  709: array(['517', '380', 'Cancer'], dtype='<U11'),
#  710: array(['424', '388', 'Unknown'], dtype='<U11'),
#  711: array(['483', '239', 'Unknown'], dtype='<U11'),
#  712: array(['440', '245', 'Non-Cl Mo'], dtype='<U11'),
#  713: array(['537', '252', 'Th'], dtype='<U11'),
#  714: array(['502', '363', 'Cancer'], dtype='<U11'),
#  715: array(['555', '292', 'Endothelial cell'], dtype='<U16'),
#  716: array(['405', '207', 'Unknown'], dtype='<U11'),
#  717: array(['447', '257', 'Unknown'], dtype='<U11'),
#  718: array(['569', '332', 'Cancer'], dtype='<U11'),
#  719: array(['482', '261', 'Non-Cl Mo'], dtype='<U11'),
#  720: array(['509', '228', 'Th'], dtype='<U11'),
#  721: array(['542', '354', 'Cancer'], dtype='<U11'),
#  722: array(['431', '235', 'Unknown'], dtype='<U11'),
#  723: array(['548', '279', 'Tc'], dtype='<U11'),
#  724: array(['411', '233', 'Cl Mo'], dtype='<U11'),
#  725: array(['415', '289', 'Endothelial cell'], dtype='<U16'),
#  726: array(['482', '386', 'Cancer'], dtype='<U11'),
#  727: array(['523', '245', 'Tc'], dtype='<U11'),
#  728: array(['492', '223', 'Endothelial cell'], dtype='<U16'),
#  729: array(['431', '337', 'B cell'], dtype='<U11'),
#  730: array(['425', '208', 'Th'], dtype='<U11'),
#  731: array(['438', '358', 'Cl MAC'], dtype='<U11'),
#  732: array(['475', '230', 'Endothelial cell'], dtype='<U16'),
#  733: array(['463', '390', 'Tc'], dtype='<U11'),
#  734: array(['435', '395', 'Th'], dtype='<U11'),
#  735: array(['486', '253', 'Th'], dtype='<U11'),
#  736: array(['477', '259', 'Non-Cl Mo'], dtype='<U11'),
#  737: array(['466', '244', 'Treg'], dtype='<U11'),
#  738: array(['452', '242', 'Cl Mo'], dtype='<U11'),
#  739: array(['526', '232', 'Unknown'], dtype='<U11'),
#  740: array(['488', '317', 'Cancer'], dtype='<U11'),
#  741: array(['462', '210', 'Unknown'], dtype='<U11'),
#  742: array(['554', '313', 'Cancer'], dtype='<U11'),
#  743: array(['584', '386', 'Cancer'], dtype='<U11'),
#  744: array(['487', '371', 'Cancer'], dtype='<U11'),
#  745: array(['431', '358', 'Cl MAC'], dtype='<U11'),
#  746: array(['439', '377', 'Cl Mo'], dtype='<U11'),
#  747: array(['472', '346', 'Non-Cl Mo'], dtype='<U11'),
#  748: array(['535', '309', 'Cancer'], dtype='<U11'),
#  749: array(['589', '277', 'Cancer'], dtype='<U11'),
#  750: array(['423', '279', 'Mast cell'], dtype='<U11'),
#  751: array(['534', '383', 'Tc'], dtype='<U11'),
#  752: array(['527', '204', 'Treg'], dtype='<U11'),
#  753: array(['466', '327', 'Endothelial cell'], dtype='<U16'),
#  754: array(['533', '220', 'Non-Cl Mo'], dtype='<U11'),
#  755: array(['452', '341', 'Unknown'], dtype='<U11'),
#  756: array(['596', '352', 'Th'], dtype='<U11'),
#  757: array(['475', '249', 'Treg'], dtype='<U11'),
#  758: array(['506', '341', 'Cancer'], dtype='<U11'),
#  759: array(['542', '383', 'Unknown'], dtype='<U11'),
#  760: array(['529', '295', 'Cancer'], dtype='<U11'),
#  761: array(['517', '293', 'Cancer'], dtype='<U11'),
#  762: array(['434', '316', 'Unknown'], dtype='<U11'),
#  763: array(['541', '394', 'Unknown'], dtype='<U11'),
#  764: array(['417', '540', 'Cancer'], dtype='<U11'),
#  765: array(['486', '426', 'Cancer'], dtype='<U11'),
#  766: array(['450', '489', 'Cancer'], dtype='<U11'),
#  767: array(['467', '504', 'Endothelial cell'], dtype='<U16'),
#  768: array(['555', '570', 'Endothelial cell'], dtype='<U16'),
#  769: array(['463', '554', 'Unknown'], dtype='<U11'),
#  770: array(['547', '519', 'Endothelial cell'], dtype='<U16'),
#  771: array(['495', '436', 'Cancer'], dtype='<U11'),
#  772: array(['578', '404', 'Mast cell'], dtype='<U11'),
#  773: array(['498', '468', 'Cancer'], dtype='<U11'),
#  774: array(['552', '530', 'Endothelial cell'], dtype='<U16'),
#  775: array(['436', '413', 'Th'], dtype='<U11'),
#  776: array(['526', '491', 'Th'], dtype='<U11'),
#  777: array(['442', '597', 'Cancer'], dtype='<U11'),
#  778: array(['551', '489', 'Cancer'], dtype='<U11'),
#  779: array(['554', '507', 'Cancer'], dtype='<U11'),
#  780: array(['541', '590', 'Cl Mo'], dtype='<U11'),
#  781: array(['497', '405', 'Cancer'], dtype='<U11'),
#  782: array(['435', '553', 'Cancer'], dtype='<U11'),
#  783: array(['487', '493', 'Cancer'], dtype='<U11'),
#  784: array(['435', '513', 'Cancer'], dtype='<U11'),
#  785: array(['469', '482', 'Cancer'], dtype='<U11'),
#  786: array(['541', '491', 'Endothelial cell'], dtype='<U16'),
#  787: array(['450', '421', 'Endothelial cell'], dtype='<U16'),
#  788: array(['410', '573', 'Non-Cl Mo'], dtype='<U11'),
#  789: array(['498', '422', 'Cancer'], dtype='<U11'),
#  790: array(['593', '526', 'Cancer'], dtype='<U11'),
#  791: array(['576', '583', 'Tc'], dtype='<U11'),
#  792: array(['574', '574', 'Th'], dtype='<U11'),
#  793: array(['511', '576', 'Unknown'], dtype='<U11'),
#  794: array(['435', '483', 'Cancer'], dtype='<U11'),
#  795: array(['556', '405', 'Unknown'], dtype='<U11'),
#  796: array(['482', '557', 'Unknown'], dtype='<U11'),
#  797: array(['483', '436', 'Endothelial cell'], dtype='<U16'),
#  798: array(['442', '550', 'Cancer'], dtype='<U11'),
#  799: array(['473', '497', 'Non-Cl Mo'], dtype='<U11'),
#  800: array(['527', '472', 'Th'], dtype='<U11'),
#  801: array(['419', '553', 'Cancer'], dtype='<U11'),
#  802: array(['586', '464', 'Cancer'], dtype='<U11'),
#  803: array(['454', '562', 'Unknown'], dtype='<U11'),
#  804: array(['479', '597', 'Cancer'], dtype='<U11'),
#  805: array(['448', '436', 'Th'], dtype='<U11'),
#  806: array(['507', '488', 'Cancer'], dtype='<U11'),
#  807: array(['516', '505', 'Cancer'], dtype='<U11'),
#  808: array(['532', '479', 'Unknown'], dtype='<U11'),
#  809: array(['441', '578', 'Cancer'], dtype='<U11'),
#  810: array(['427', '597', 'Non-Cl Mo'], dtype='<U11'),
#  811: array(['571', '421', 'Cancer'], dtype='<U11'),
#  812: array(['491', '446', 'Endothelial cell'], dtype='<U16'),
#  813: array(['532', '562', 'Endothelial cell'], dtype='<U16'),
#  814: array(['598', '458', 'Cancer'], dtype='<U11'),
#  815: array(['538', '535', 'Endothelial cell'], dtype='<U16'),
#  816: array(['518', '527', 'Cancer'], dtype='<U11'),
#  817: array(['462', '663', 'Cancer'], dtype='<U11'),
#  818: array(['492', '631', 'Tc'], dtype='<U11'),
#  819: array(['506', '780', 'Cancer'], dtype='<U11'),
#  820: array(['552', '761', 'Alt MAC'], dtype='<U11'),
#  821: array(['503', '609', 'Unknown'], dtype='<U11'),
#  822: array(['426', '750', 'Neutrophils'], dtype='<U11'),
#  823: array(['494', '779', 'Cancer'], dtype='<U11'),
#  824: array(['591', '700', 'Tc'], dtype='<U11'),
#  825: array(['515', '618', 'Th'], dtype='<U11'),
#  826: array(['550', '778', 'Cl MAC'], dtype='<U11'),
#  827: array(['510', '678', 'Tc'], dtype='<U11'),
#  828: array(['497', '623', 'Th'], dtype='<U11'),
#  829: array(['521', '774', 'Neutrophils'], dtype='<U11'),
#  830: array(['472', '673', 'Tc'], dtype='<U11'),
#  831: array(['504', '716', 'Cl Mo'], dtype='<U11'),
#  832: array(['512', '765', 'Non-Cl Mo'], dtype='<U11'),
#  833: array(['443', '620', 'Cancer'], dtype='<U11'),
#  834: array(['413', '776', 'Cl Mo'], dtype='<U11'),
#  835: array(['466', '699', 'Th'], dtype='<U11'),
#  836: array(['565', '783', 'Cl MAC'], dtype='<U11'),
#  837: array(['569', '630', 'Unknown'], dtype='<U11'),
#  838: array(['415', '709', 'Th'], dtype='<U11'),
#  839: array(['500', '671', 'Endothelial cell'], dtype='<U16'),
#  840: array(['428', '650', 'Cancer'], dtype='<U11'),
#  841: array(['452', '662', 'Cancer'], dtype='<U11'),
#  842: array(['467', '648', 'Cancer'], dtype='<U11'),
#  843: array(['556', '624', 'Cl MAC'], dtype='<U11'),
#  844: array(['567', '692', 'Cl Mo'], dtype='<U11'),
#  845: array(['453', '747', 'Unknown'], dtype='<U11'),
#  846: array(['439', '694', 'Unknown'], dtype='<U11'),
#  847: array(['598', '644', 'Cancer'], dtype='<U11'),
#  848: array(['448', '727', 'Cl Mo'], dtype='<U11'),
#  849: array(['497', '727', 'Endothelial cell'], dtype='<U16'),
#  850: array(['493', '681', 'Endothelial cell'], dtype='<U16'),
#  851: array(['508', '722', 'Cl Mo'], dtype='<U11'),
#  852: array(['477', '717', 'Cl Mo'], dtype='<U11'),
#  853: array(['422', '798', 'Cancer'], dtype='<U11'),
#  854: array(['410', '622', 'Endothelial cell'], dtype='<U16'),
#  855: array(['593', '713', 'Endothelial cell'], dtype='<U16'),
#  856: array(['474', '788', 'Cancer'], dtype='<U11'),
#  857: array(['421', '692', 'Unknown'], dtype='<U11'),
#  858: array(['498', '651', 'T other'], dtype='<U11'),
#  859: array(['532', '624', 'Th'], dtype='<U11'),
#  860: array(['436', '645', 'Cancer'], dtype='<U11'),
#  861: array(['457', '728', 'Cl Mo'], dtype='<U11'),
#  862: array(['466', '726', 'Endothelial cell'], dtype='<U16'),
#  863: array(['555', '943', 'Cancer'], dtype='<U11'),
#  864: array(['478', '948', 'Cancer'], dtype='<U11'),
#  865: array(['430', '838', 'Cancer'], dtype='<U11'),
#  866: array(['456', '953', 'Cancer'], dtype='<U11'),
#  867: array(['594', '926', 'Endothelial cell'], dtype='<U16'),
#  868: array(['511', '876', 'Alt MAC'], dtype='<U11'),
#  869: array(['436', '900', 'Cancer'], dtype='<U11'),
#  870: array(['468', '956', 'Cancer'], dtype='<U11'),
#  871: array(['473', '915', 'Endothelial cell'], dtype='<U16'),
#  872: array(['435', '823', 'Cancer'], dtype='<U11'),
#  873: array(['519', '839', 'Cancer'], dtype='<U11'),
#  874: array(['500', '873', 'Unknown'], dtype='<U11'),
#  875: array(['477', '846', 'Th'], dtype='<U11'),
#  876: array(['535', '948', 'Cancer'], dtype='<U11'),
#  877: array(['524', '861', 'Cancer'], dtype='<U11'),
#  878: array(['502', '958', 'Treg'], dtype='<U11'),
#  879: array(['578', '916', 'Endothelial cell'], dtype='<U16'),
#  880: array(['587', '958', 'Cancer'], dtype='<U11'),
#  881: array(['492', '951', 'Neutrophils'], dtype='<U11'),
#  882: array(['500', '854', 'Endothelial cell'], dtype='<U16'),
#  883: array(['443', '976', 'Cancer'], dtype='<U11'),
#  884: array(['597', '898', 'Cancer'], dtype='<U11'),
#  885: array(['518', '981', 'Th'], dtype='<U11'),
#  886: array(['526', '912', 'Alt MAC'], dtype='<U11'),
#  887: array(['452', '828', 'Cl Mo'], dtype='<U11'),
#  888: array(['459', '896', 'Endothelial cell'], dtype='<U16'),
#  889: array(['532', '870', 'Cancer'], dtype='<U11'),
#  890: array(['433', '868', 'Unknown'], dtype='<U11'),
#  891: array(['594', '866', 'Neutrophils'], dtype='<U11'),
#  892: array(['502', '898', 'Neutrophils'], dtype='<U11'),
#  893: array(['569', '913', 'Th'], dtype='<U11'),
#  894: array(['495', '864', 'Neutrophils'], dtype='<U11'),
#  895: array(['429', '935', 'Cancer'], dtype='<U11'),
#  896: array(['448', '881', 'Cl MAC'], dtype='<U11'),
#  897: array(['511', '962', 'Th'], dtype='<U11'),
#  898: array(['508', '916', 'Endothelial cell'], dtype='<U16'),
#  899: array(['464', '880', 'Unknown'], dtype='<U11'),
#  900: array(['483', '912', 'Cl MAC'], dtype='<U11'),
#  901: array(['467', '931', 'Cl Mo'], dtype='<U11'),
#  902: array(['599', '828', 'Neutrophils'], dtype='<U11'),
#  903: array(['488', '904', 'Unknown'], dtype='<U11'),
#  904: array(['492', '911', 'Unknown'], dtype='<U11'),
#  905: array(['541', '874', 'Cancer'], dtype='<U11'),
#  906: array(['423', '867', 'Non-Cl Mo'], dtype='<U11'),
#  907: array(['571', '888', 'Cancer'], dtype='<U11'),
#  908: array(['499', '903', 'Neutrophils'], dtype='<U11'),
#  909: array(['522', '883', 'Cl Mo'], dtype='<U11'),
#  910: array(['678', '2', 'Unknown'], dtype='<U11'),
#  911: array(['698', '108', 'Endothelial cell'], dtype='<U16'),
#  912: array(['689', '118', 'Tc'], dtype='<U11'),
#  913: array(['732', '82', 'Unknown'], dtype='<U11'),
#  914: array(['658', '180', 'Unknown'], dtype='<U11'),
#  915: array(['689', '101', 'Endothelial cell'], dtype='<U16'),
#  916: array(['693', '132', 'Cancer'], dtype='<U11'),
#  917: array(['681', '19', 'Cancer'], dtype='<U11'),
#  918: array(['770', '147', 'Unknown'], dtype='<U11'),
#  919: array(['686', '69', 'Cl Mo'], dtype='<U11'),
#  920: array(['771', '21', 'Cancer'], dtype='<U11'),
#  921: array(['676', '153', 'Cancer'], dtype='<U11'),
#  922: array(['716', '56', 'Th'], dtype='<U11'),
#  923: array(['725', '106', 'Cancer'], dtype='<U11'),
#  924: array(['725', '60', 'Th'], dtype='<U11'),
#  925: array(['705', '152', 'Cancer'], dtype='<U11'),
#  926: array(['702', '83', 'Tc'], dtype='<U11'),
#  927: array(['706', '43', 'Endothelial cell'], dtype='<U16'),
#  928: array(['698', '6', 'Cancer'], dtype='<U11'),
#  929: array(['771', '174', 'Cl MAC'], dtype='<U11'),
#  930: array(['736', '40', 'Alt MAC'], dtype='<U11'),
#  931: array(['651', '16', 'Cancer'], dtype='<U11'),
#  932: array(['719', '83', 'Unknown'], dtype='<U11'),
#  933: array(['705', '90', 'Cl MAC'], dtype='<U11'),
#  934: array(['698', '120', 'Cl MAC'], dtype='<U11'),
#  935: array(['697', '88', 'Tc'], dtype='<U11'),
#  936: array(['628', '116', 'Cl Mo'], dtype='<U11'),
#  937: array(['669', '39', 'Cancer'], dtype='<U11'),
#  938: array(['738', '174', 'Tc'], dtype='<U11'),
#  939: array(['661', '83', 'Cancer'], dtype='<U11'),
#  940: array(['616', '140', 'Cl MAC'], dtype='<U11'),
#  941: array(['714', '31', 'Endothelial cell'], dtype='<U16'),
#  942: array(['644', '128', 'Non-Cl Mo'], dtype='<U11'),
#  943: array(['616', '74', 'Cancer'], dtype='<U11'),
#  944: array(['719', '16', 'Endothelial cell'], dtype='<U16'),
#  945: array(['636', '2', 'Cl MAC'], dtype='<U11'),
#  946: array(['699', '48', 'Cl MAC'], dtype='<U11'),
#  947: array(['696', '78', 'T other'], dtype='<U11'),
#  948: array(['662', '44', 'Cancer'], dtype='<U11'),
#  949: array(['736', '164', 'Tc'], dtype='<U11'),
#  950: array(['698', '60', 'Cl Mo'], dtype='<U11'),
#  951: array(['699', '65', 'Cl Mo'], dtype='<U11'),
#  952: array(['660', '61', 'Unknown'], dtype='<U11'),
#  953: array(['678', '90', 'Cl MAC'], dtype='<U11'),
#  954: array(['691', '1', 'Cancer'], dtype='<U11'),
#  955: array(['735', '190', 'Cl MAC'], dtype='<U11'),
#  956: array(['645', '180', 'Cancer'], dtype='<U11'),
#  957: array(['745', '100', 'Cancer'], dtype='<U11'),
#  958: array(['619', '82', 'Cancer'], dtype='<U11'),
#  959: array(['778', '64', 'Unknown'], dtype='<U11'),
#  960: array(['760', '166', 'Endothelial cell'], dtype='<U16'),
#  961: array(['765', '194', 'Th'], dtype='<U11'),
#  962: array(['704', '71', 'Alt MAC'], dtype='<U11'),
#  963: array(['697', '14', 'Cancer'], dtype='<U11'),
#  964: array(['708', '15', 'Cl MAC'], dtype='<U11'),
#  965: array(['721', '147', 'Cancer'], dtype='<U11'),
#  966: array(['690', '51', 'Endothelial cell'], dtype='<U16'),
#  967: array(['637', '120', 'Alt MAC'], dtype='<U11'),
#  968: array(['713', '73', 'Th'], dtype='<U11'),
#  969: array(['661', '1', 'Unknown'], dtype='<U11'),
#  970: array(['798', '174', 'Unknown'], dtype='<U11'),
#  971: array(['767', '50', 'Tc'], dtype='<U11'),
#  972: array(['677', '68', 'Cancer'], dtype='<U11'),
#  973: array(['739', '182', 'Endothelial cell'], dtype='<U16'),
#  974: array(['628', '134', 'Cl MAC'], dtype='<U11'),
#  975: array(['733', '133', 'Cancer'], dtype='<U11'),
#  976: array(['776', '32', 'Cancer'], dtype='<U11'),
#  977: array(['706', '64', 'Int Mo'], dtype='<U11'),
#  978: array(['684', '385', 'Cancer'], dtype='<U11'),
#  979: array(['763', '254', 'Unknown'], dtype='<U11'),
#  980: array(['665', '265', 'Cancer'], dtype='<U11'),
#  981: array(['772', '257', 'Unknown'], dtype='<U11'),
#  982: array(['608', '367', 'Th'], dtype='<U11'),
#  983: array(['739', '295', 'Cl Mo'], dtype='<U11'),
#  984: array(['620', '282', 'Cancer'], dtype='<U11'),
#  985: array(['628', '334', 'Tc'], dtype='<U11'),
#  986: array(['664', '289', 'Cancer'], dtype='<U11'),
#  987: array(['773', '286', 'Th'], dtype='<U11'),
#  988: array(['659', '218', 'Cancer'], dtype='<U11'),
#  989: array(['755', '207', 'Endothelial cell'], dtype='<U16'),
#  990: array(['675', '310', 'Cl MAC'], dtype='<U11'),
#  991: array(['789', '229', 'Alt MAC'], dtype='<U11'),
#  992: array(['781', '215', 'Unknown'], dtype='<U11'),
#  993: array(['719', '273', 'Cancer'], dtype='<U11'),
#  994: array(['701', '265', 'Cancer'], dtype='<U11'),
#  995: array(['786', '206', 'Unknown'], dtype='<U11'),
#  996: array(['751', '233', 'Unknown'], dtype='<U11'),
#  997: array(['741', '308', 'B cell'], dtype='<U11'),
#  998: array(['648', '290', 'Cancer'], dtype='<U11'),
#  999: array(['618', '293', 'Unknown'], dtype='<U11'),
#  ...}

# %%
# example images of cells to make sure converting went well
plt.imshow(segm_nms['nucleiImage'])
plt.show()

plt.imshow(segm_nms['nucleiOccupancyIndexed'])
plt.show()
plt.imshow(segm_nms['occupancy_image'])

plt.show()

# %%
# Load in first patient
pi = pd.read_excel(f'{data_path}/raw/LUAD Clinical Data.xlsx')
patientinfocols = pi.columns
df = pd.DataFrame(master_dict['LUAD_D001']).T
df.columns = ['x_pix', 'y_pix', 'celltype']

df = pd.concat([df, pd.concat([pi[pi['Key'] == 'LUAD_D001']]*len(df), ignore_index=True)], axis=1)
df['ID'] = df['Key'].str[5:] + '_' + df.index.astype(str)

# stack rest of the patients on top of original patient df to create one big df
# index is cell number per patient

for i in range(2, 417):
    no = format(i, '03d')
    pat = 'LUAD_D' + no
    df2 = pd.DataFrame(master_dict[pat]).T
    df2.columns = ['x_pix', 'y_pix', 'celltype']

    df2 = pd.concat([df2, pd.concat([pi[pi['Key'] == pat]]*len(df2), ignore_index=True)], axis=1)
    df2['ID'] = df2['Key'].str[5:] + '_' + df2.index.astype(str)
    df = pd.concat([df,df2], axis=0)

# %%
# Get date
date = datetime.now().strftime("%Y%m%d")
# save full df to csv
df.to_csv(f"{data_path}/celldata/celldata_all_clean_{date}.csv", index = False)

# %%
# Format the data for celldistance py script
celldata = df[['ID', 'celltype','Key', 'x_pix', 'y_pix']]
celldata = celldata.rename(columns={"Key":"Patient_ID","ID": "cellID", 'x_pix':'Location_Center_X', 'y_pix':'Location_Center_Y'})
celldata.to_csv(f"{data_path}/celldata/celldata_{date}.csv", index = False)

celldata
# Out:
#          cellID          celltype Patient_ID Location_Center_X  \
# 0        D001_0            Cancer  LUAD_D001                93
# 1        D001_1                Tc  LUAD_D001                74
# 2        D001_2                Tc  LUAD_D001               167
# 3        D001_3            Cancer  LUAD_D001               134
# 4        D001_4  Endothelial cell  LUAD_D001               142
# ...         ...               ...        ...               ...
# 2881  D416_2881            Cl MAC  LUAD_D416               281
# 2882  D416_2882           Unknown  LUAD_D416               385
# 2883  D416_2883            Cancer  LUAD_D416               363
# 2884  D416_2884            Cancer  LUAD_D416               357
# 2885  D416_2885            Cancer  LUAD_D416               369
#
#      Location_Center_Y
# 0                  159
# 1                  186
# 2                  131
# 3                  116
# 4                  122
# ...                ...
# 2881               879
# 2882               907
# 2883               992
# 2884               994
# 2885               995
#
# [1640317 rows x 5 columns]
