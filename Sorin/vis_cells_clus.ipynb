# %%
import pandas as pd 
import os 
from datetime import datetime 
import matplotlib.pyplot as plt
import numpy as np

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# c:\Users\jhroe\Desktop\Thesis\Clean\CellularCommunityAnalysisNSCLC\Sorin

# %%
# date = datetime.now().strftime("%Y%m%d")
# pi = pd.read_excel('Data/raw/LUAD Clinical Data.xlsx')

# Get current directory
current_directory = os.getcwd()
data_path = current_directory + '/Data/'

# Set path 
df = pd.read_csv(f"{data_path}/clustered/full_cd_clus_20_40_49.csv").rename(columns={'cluster': 'agglomerateto_275'})
df_loc = pd.read_csv(f"{data_path}/celldata/celldata_20240313.csv")[['cellID', 'Location_Center_X', 'Location_Center_Y']].rename(columns={'cellID': 'source_ID', 'cluster': 'agglomerateto_275'})

# Merge location data 
df_full= pd.merge(df, df_loc, on='source_ID', how='inner')

# %%
df_full['Patient_ID'].unique()
# Out:
# array(['LUAD_D001', 'LUAD_D002', 'LUAD_D003', 'LUAD_D004', 'LUAD_D005',
#        'LUAD_D006', 'LUAD_D007', 'LUAD_D008', 'LUAD_D009', 'LUAD_D010',
#        'LUAD_D011', 'LUAD_D012', 'LUAD_D013', 'LUAD_D014', 'LUAD_D015',
#        'LUAD_D016', 'LUAD_D017', 'LUAD_D018', 'LUAD_D019', 'LUAD_D020',
#        'LUAD_D021', 'LUAD_D022', 'LUAD_D023', 'LUAD_D024', 'LUAD_D025',
#        'LUAD_D026', 'LUAD_D027', 'LUAD_D028', 'LUAD_D029', 'LUAD_D030',
#        'LUAD_D031', 'LUAD_D032', 'LUAD_D033', 'LUAD_D034', 'LUAD_D035',
#        'LUAD_D036', 'LUAD_D037', 'LUAD_D038', 'LUAD_D039', 'LUAD_D040',
#        'LUAD_D041', 'LUAD_D042', 'LUAD_D043', 'LUAD_D044', 'LUAD_D045',
#        'LUAD_D046', 'LUAD_D047', 'LUAD_D048', 'LUAD_D049', 'LUAD_D050',
#        'LUAD_D051', 'LUAD_D052', 'LUAD_D053', 'LUAD_D054', 'LUAD_D055',
#        'LUAD_D056', 'LUAD_D057', 'LUAD_D058', 'LUAD_D059', 'LUAD_D060',
#        'LUAD_D061', 'LUAD_D062', 'LUAD_D063', 'LUAD_D064', 'LUAD_D065',
# ...

# %%
df_full
# Out:
#         Patient_ID  source_ID source_cluster   Alt.MAC    B.cell    Cancer  \
# 0        LUAD_D001     D001_0         Cancer  0.166667  0.000000  0.166667
# 1        LUAD_D001  D001_1000           Treg  0.000000  0.000000  0.000000
# 2        LUAD_D001  D001_1010        Unknown  0.000000  0.000000  0.000000
# 3        LUAD_D001  D001_1011        Unknown  0.000000  0.000000  0.000000
# 4        LUAD_D001  D001_1013        Unknown  0.142857  0.000000  0.000000
# ...            ...        ...            ...       ...       ...       ...
# 1637717  LUAD_D213  D213_1771         Cancer  0.000000  0.076923  0.923077
# 1637718  LUAD_D213  D213_2703         Cancer  0.000000  0.090909  0.909091
# 1637719  LUAD_D213  D213_4040         Cancer  0.000000  0.100000  0.900000
# 1637720  LUAD_D213  D213_4896         Cancer  0.000000  0.066667  0.933333
# 1637721  LUAD_D213  D213_2455         Cancer  0.000000  0.000000  0.857143
#
# ...

# %%
# 49 colors that are (relatively distinct)
colors = [
    "#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd",
    "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf",
    "#aec7e8", "#ffbb78", "#98df8a", "#ff9896", "#c5b0d5",
    "#c49c94", "#f7b6d2", "#c7c7c7", "#dbdb8d", "#9edae5",
    "#393b79", "#5254a3", "#6b6ecf", "#9c9ede", "#637939",
    "#8ca252", "#b5cf6b", "#cedb9c", "#8c6d31", "#bd9e39",
    "#e7ba52", "#e7cb94", "#843c39", "#ad494a", "#d6616b",
    "#e7969c", "#7b4173", "#a55194", "#ce6dbd", "#de9ed6",
    "#3182bd", "#6baed6", "#9ecae1", "#c6dbef", "#e6550d",
    "#fd8d3c", "#fdae6b", "#fdd0a2", "#31a354", "#74c476"
]
# Cluster numbers with highest treg content in clus = 40
treg_clusters_40 = [28, 26, 27, 37, 22, 49, 47, 34, 44, 39]

treg_clusters_20 = [14, 7, 18, 10, 17, 10]

# %%
def show_spatial_clus(data, patient, no_clus=20, interesting_clusters=None):
    pat_df = data.loc[data['Patient_ID'] == patient]
    if not interesting_clusters:
        for cluster in range(1, no_clus+1): 
            clus_df = pat_df.loc[pat_df[f'agglomerateto_{no_clus}'] == cluster]
            plt.scatter(clus_df['Location_Center_X'], clus_df['Location_Center_Y'], color=colors[cluster-1],s=5, label=cluster)
    else:
        for cluster in range(1, no_clus+1): 
            clus_df = pat_df.loc[pat_df[f'agglomerateto_{no_clus}'] == cluster]
            if cluster in interesting_clusters:
                plt.scatter(clus_df['Location_Center_X'], clus_df['Location_Center_Y'], color=colors[cluster-1],s=5, label=cluster)
            else:
                plt.scatter(clus_df['Location_Center_X'], clus_df['Location_Center_Y'], color="#000000",s=5, label='rest')
        
    # Get unique labels
    handles, labels = plt.gca().get_legend_handles_labels()
    unique_labels = {}
    for handle, label in zip(handles, labels):
        if label not in unique_labels:
            unique_labels[label] = handle

    plt.legend(unique_labels.values(), unique_labels.keys(),bbox_to_anchor=(1.05, 1), loc='upper left', scatterpoints=20)
    plt.xlabel('x position')
    plt.ylabel('y position')
    plt.title(f'Spatial cell location colored by cluster from patient: {patient}')
    return None




# show_spatial_clus(df_full, 'LUAD_D004', 40)
show_spatial_clus(df_full, 'LUAD_D003', 20, interesting_clusters=treg_clusters_20)

# %%
df_full.loc[df_full['Patient_ID'] == 'LUAD_D001']['agglomerateto_20'].nunique()
# Out:
# 17
